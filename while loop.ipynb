# %%
while True:
    print('Hello Python')
# Out:
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# ...

# %%
counter=0

# %%
while True:
    print('Hello Python')
    counter+=1
# Out:
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# ...

# %%
print(counter)
# Out:
# 43462

# %%
prompt='Tell my anything that you want to iterate or enter"quit" to stop the loop '

# %%
message=""
while message!='quit':
    message=input(prompt)
    print(message)
# Out:
# Tell my anything that you want to titerate or enter"quit" to stop the loop Hello world
# Hello world
# Tell my anything that you want to titerate or enter"quit" to stop the loop Education world
# Education world
# Tell my anything that you want to titerate or enter"quit" to stop the loop quit
# quit

# %%
message=""
while message!='quit':
    message=input(prompt)
    if message != 'quit':
        print(message)
# Out:
# Tell my anything that you want to titerate or enter"quit" to stop the loop Education world
# Education world
# Tell my anything that you want to titerate or enter"quit" to stop the loop quit

# %%
# flag variable
flag=True
while flag:
    message=input(prompt)
    
    if message == 'quit':
        flag=False
    else:
        print(message)
# Out:
# Tell my anything that you want to titerate or enter"quit" to stop the loop 23
# 23
# Tell my anything that you want to titerate or enter"quit" to stop the loop 34
# 34
# Tell my anything that you want to titerate or enter"quit" to stop the loop 12
# 12
# Tell my anything that you want to titerate or enter"quit" to stop the loop 56
# 56
# Tell my anything that you want to titerate or enter"quit" to stop the loop Hello
# Hello
# Tell my anything that you want to titerate or enter"quit" to stop the loop 45
# 45
# Tell my anything that you want to titerate or enter"quit" to stop the loop 14 august
# 14 august
# Tell my anything that you want to titerate or enter"quit" to stop the loop quit

# %%
indicator=0
while indicator<=5:
    print(indicator)
    indicator+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
indicator
# Out:
# 6

# %% [markdown]
# # break & continue

# %%
prompt='Tell my anything that you want to iterate or enter"quit" to stop the loop '

# %%
while True:
    message=input(prompt)
    if message == 'quit':
        break
    else :
        print(message)
# Out:
# Tell my anything that you want to iterate or enter"quit" to stop the loop country
# country
# Tell my anything that you want to iterate or enter"quit" to stop the loop city
# city
# Tell my anything that you want to iterate or enter"quit" to stop the loop 12
# 12
# Tell my anything that you want to iterate or enter"quit" to stop the loop 34
# 34
# Tell my anything that you want to iterate or enter"quit" to stop the loop quit

# %%
a_list=['pakistan','india','japan','china','turkey']

# %%
for i in a_list:
    if i.lower() == 'japan':
        break
    else:
        print(i)
# Out:
# pakistan
# india

# %%
num=0
while num<10 :
    num+=1
    if num %2 == 0 :
        continue
    else:
        print(num)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # while loop in practice

# %%
# Start with users that need to be verified,
# and an empty list to hold confirmed users.

unconfirmed_users = ['alice', 'brian', 'candace']
confirmed_users = []

# Verify each user until there are no more unconfirmed users.
# Move each verified user into the list of confirmed users.

while unconfirmed_users:
    current_user = unconfirmed_users.pop()

    print("Verifying user: " + current_user.title())
    confirmed_users.append(current_user)
# Out:
# Verifying user: Candace
# Verifying user: Brian
# Verifying user: Alice

# %%
# Display all confirmed users.
print("\nThe following users have been confirmed:")
for confirmed_user in confirmed_users:
    print(confirmed_user.title())
# Out:
# The following users have been confirmed:
# Candace
# Brian
# Alice

# %%
pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
print(pets)
# Out:
# ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']

# %%
while 'cat' in pets:
    pets.remove('cat')

print(pets)
# Out:
# ['dog', 'dog', 'goldfish', 'rabbit']

# %%
responses = {}
# Set a flag to indicate that polling is active.
polling_active = True
while polling_active:
    # Prompt for the person's name and response.
    name = input("\nWhat is your name? ")
    response = input("Which mountain would you like to climb someday? ")
    # Store the response in the dictionary:
    responses[name] = response

     # Find out if anyone else is going to take the poll.
    repeat = input("Would you like to let another person respond? (yes/ no) ")
    if repeat == 'no':
        polling_active = False
# Out:
# What is your name? umer
# Which mountain would you like to climb someday? k2
# Would you like to let another person respond? (yes/ no) yes
#
# What is your name? ali
# Which mountain would you like to climb someday? everst
# Would you like to let another person respond? (yes/ no) no

# %%
# Polling is complete. Show the results.
print("\n--- Poll Results ---")
for name, response in responses.items():
    print(name + " would like to climb " + response + ".")
# Out:
# --- Poll Results ---
# umer would like to climb k2.
# ali would like to climb everst.

# %%
responses
# Out:
# {'umer': 'k2', 'ali': 'everst'}
